# %% [markdown]
# Playing with **Excellent Pandas Notebooks from book Pandas Cookbook:** [kaggle discussion](https://www.kaggle.com/discussions/getting-started/120943)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Make the graphs a bit prettier and bigger
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# # 1. Reading data from a .csv file

# %%
df_broken = pd.read_csv('../data/bikes_montreal_2012.csv', encoding='ISO-8859-1')
df_broken[:3]
# Out:
#   Date;Berri 1;Brébeuf (données non disponibles);Côte-Sainte-Catherine;Maisonneuve 1;Maisonneuve 2;du Parc;Pierre-Dupuy;Rachel1;St-Urbain (données non disponibles)
# 0                   01/01/2012;35;;0;38;51;26;10;16;
# 1                   02/01/2012;83;;1;68;153;53;6;43;
# 2                 03/01/2012;135;;2;104;248;89;3;58;

# %%
df_fixed = pd.read_csv('../data/bikes_montreal_2012.csv', 
                       encoding='latin1', # Change encoding
                       sep=';', # New separator
                       parse_dates=['Date'], # Parse the dates
                       dayfirst=True, # Our dates have the day first instead of the month
                       index_col='Date' # Set the index to be Date column
                      )
df_fixed[:3]
# Out:
#             Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine
# Date
# 2012-01-01       35                                NaN                      0  \
# 2012-01-02       83                                NaN                      1
# 2012-01-03      135                                NaN                      2
#
#             Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1
# Date
# 2012-01-01             38             51       26            10       16  \
# 2012-01-02             68            153       53             6       43
# 2012-01-03            104            248       89             3       58
#
#             St-Urbain (données non disponibles)
# Date
# 2012-01-01                                  NaN
# 2012-01-02                                  NaN
# 2012-01-03                                  NaN

# %% [markdown]
# ## 1.2 Selecting a column

# %%
df_fixed['Berri 1']
# Out:
# Date
# 2012-01-01      35
# 2012-01-02      83
# 2012-01-03     135
# 2012-01-04     144
# 2012-01-05     197
#               ...
# 2012-11-01    2405
# 2012-11-02    1582
# 2012-11-03     844
# 2012-11-04     966
# 2012-11-05    2247
# Name: Berri 1, Length: 310, dtype: int64

# %% [markdown]
# ## 1.3 Plotting a column

# %%
df_fixed['Berri 1'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_fixed.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## 1.4 Putting all that together

# %%
df_bikes = pd.read_csv('../data/bikes_montreal_2012.csv',
                       encoding='latin1',
                       sep=';',
                       parse_dates=['Date'],
                       dayfirst=True,
                       index_col='Date'
            ).dropna(axis=1)
df_bikes['du Parc'].plot()
# Out:
# <Axes: xlabel='Date'>
